# %%
import requests
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from urllib.parse import quote

# %%
from tqdm.notebook import tqdm
driver = webdriver.Chrome('C:\\Users\\Bestc\\Desktop\\빅데이터 지능형 서비스 개발과정(멀티캠퍼스)\\설치프로그램\\Selenium\\chromedriver.exe')
search_words = '건강'
URL = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query=' + quote(search_words)
driver.get(URL)
import re
raw_data_list = []
for i in tqdm(range(400)):
    try:
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        raw_data = soup.select_one('section > div.api_subject_bx > .group_news > .list_news').text
        raw_data = re.sub('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]', '', raw_data)
        raw_data_list.append(raw_data)
        driver.find_element_by_xpath("//*[@id='main_pack']/div[2]/div/a[2]").click()
        time.sleep(3)
    except:
        print(i)
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]

# %%
len(raw_data_list)
# Out:
# 400

# %%
df = pd.DataFrame(list(raw_data_list), columns = ['data'])
df.head()
# Out:
#                                                 data
# 0        문서 저장하기  에 저장  바로가기  뉴시스시간 전네이버뉴스 대상 집으로...
# 1        문서 저장하기  에 저장  바로가기  새전북신문시간 전 천지양 수면 건강...
# 2        문서 저장하기  에 저장  바로가기  마이데일리시간 전네이버뉴스 건강 회...
# 3        문서 저장하기  에 저장  바로가기  스포츠서울시간 전네이버뉴스 러쉬코리...
# 4        문서 저장하기  에 저장  바로가기  파이낸셜뉴스언론사 선정일 전네이버뉴...

# %%
df.data.nunique()
# Out:
# 400

# %%
df.data.isnull().sum()
# Out:
# 0

# %%
sdf = pd.read_csv('C:\\Workspace\\python\\Data_Science\\dataA\\한국어불용어100.txt', encoding ='UTF-8', sep = '\s+', header = None)
sdf.head()
# Out:
#    0    1         2
# 0  이  VCP  0.018280
# 1  있   VA  0.011699
# 2  하   VV  0.009774
# 3  것  NNB  0.009733
# 4  들  XSN  0.006898

# %%
from konlpy.tag import Okt
okt = Okt()
stopwords = set(sdf[0])

# %%
tokenized_data = []
for sentence in tqdm(df.data):
    morphs = okt.morphs(sentence.strip(), stem = True)
    temp_list = [word for word in morphs if word not in stopwords]
    tokenized_data.extend(temp_list)
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]

# %%
len(tokenized_data)
# Out:
# 243558

# %%
tokenized_data[:10]
# Out:
# ['문서', '저장', '하다', '에', '저장', '바로가기', '뉴시스', '네이버뉴스', '대상', '으로']

# %%
# 한글 폰트 적용
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fonm
from matplotlib import font_manager, rc
mpl.rcParams['axes.unicode_minus'] = False
font_path = "C:/Windows/Fonts/정직_1.ttf"
font = fonm.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
import nltk
stoptext = '''하다 문서 저장 에 바로가기 언론사 분 선정 측 의 사단 네이버뉴스 과 는 있다 를 인 은 와 하고 으로
              관련 로 없다 경 당 없다 날 이다 찾다 대해 첫 되다 도 뉴스 에서 을 뉴시스 조선일보 한국 연합뉴스 대 회 비단 위 기
              당시 대한 은 예비 
'''
stopwords2 = stoptext.split()
new_tokens = [word for word in tokenized_data if word not in stopwords2]
keywords = nltk.Text(new_tokens, name = '윤석열 검색결과')
plt.figure(figsize = (15, 6))
keywords.plot(50)
plt.show()

# %%
from wordcloud import WordCloud
from PIL import Image

# %%
data = keywords.vocab().most_common(300)
wc = WordCloud(
    font_path = font_path, relative_scaling = 0.2,
    background_color = 'white'
).generate_from_frequencies(dict(data))
plt.figure(figsize = (15, 10))
plt.imshow(wc)
plt.axis('off')
plt.show()
